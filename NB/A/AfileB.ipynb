# %% [markdown]
# # File to Sampling
# #### By: Javier Orduz
# [license-badge]: https://img.shields.io/badge/License-CC-orange
# [license]: https://creativecommons.org/licenses/by-nc-sa/3.0/deed.en
# [![CC License][license-badge]][license]
# [![DS](https://img.shields.io/badge/downloads-DS-green)](https://github.com/Earlham-College/DS_Fall_2022)
# [![Github](https://img.shields.io/badge/jaorduz-repos-blue)](https://github.com/jaorduz/)
# [![Github](https://img.shields.io/badge/jaorduc-repos-blue)](https://github.com/jaorduc/)
# ![Follow @jaorduc](https://img.shields.io/twitter/follow/jaorduc?label=follow&logo=twitter&logoColor=lkj&style=plastic)

# %% [markdown]
# <div class="alert  alert-block alert-info" style="margin-top: 1px">
#     <ol>
#         <li><a href="#unData">Import modules</a></li>
#          <!-- <ol>
#              <li><a href="#reData">Reading</a></li>
#          </ol> -->
#         <li><a href="#daExploration">Read CSV</a></li>
#         <li><a href="#showData">Show data</a></li>
#         <li><a href="#exerci">Exercises</a></li>
#     </ol>
# </div>
# <br>
# <hr>

# %%
import pandas as pd

# %%
df = pd.read_csv("../../DATA/FuelConsumption.csv")

# %%
df.head(5)
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# 1                   9.6                        29           221
# 2                   5.9                        48           136
# 3                  11.1                        25           255
# 4                  10.6                        27           244

# %%
subset = df.sample(n=4)

# %%
subset.head()
# Out:
#      MODELYEAR       MAKE                   MODEL     VEHICLECLASS  \
# 556       2014     JAGUAR         XJ SUPERCHARGED        FULL-SIZE
# 292       2014   CHRYSLER      TOWN & COUNTRY FFV          MINIVAN
# 223       2014  CHEVROLET  EXPRESS 2500 PASSENGER  VAN - PASSENGER
# 990       2014     TOYOTA                    RAV4      SUV - SMALL
#
#      ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  \
# 556         5.0          8          AS8        Z                  15.8
# 292         3.6          6           A6        E                  19.7
# 223         4.8          8           A6        X                  21.1
# 990         2.5          4          AS6        X                  10.0
#
#      FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# 556                 10.2                  13.3                        21
# 292                 13.3                  16.8                        17
# 223                 14.2                  18.0                        16
# 990                  7.6                   8.9                        32
#
#      CO2EMISSIONS
# 556           306
# 292           269
# 223           414
# 990           205

# %% [markdown]
# # Exercise
# For this exercise, you have the flexibility to opt for either embedding a link to your personal repository or integrating screenshots directly into the document you'll submit via Moodle. Should you select the latter alternative, kindly exercise caution and meticulous attention while managing the screenshots.
#
# 1. Read another data from the folder and show the first ten elements.
# 2. Explain the sampling concept.
# 3. Read another data from the folder and show the 10% of elements.
# 4. Do you think there enough data to make a good Statistics.
# 5. Submmit your report in Moodle. Template https://www.overleaf.com/read/xqcnnnrsspcp
